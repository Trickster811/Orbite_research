# %%
# %pip install torch torchvision syft
# %pip install pysyft
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Skipping /usr/lib/python3.12/dist-packages/tqdm-4.66.5.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: torch in /home/MacNight_nj/.local/lib/python3.12/site-packages (2.7.1)
# Requirement already satisfied: torchvision in /home/MacNight_nj/.local/lib/python3.12/site-packages (0.22.1)
# Requirement already satisfied: syft in /home/MacNight_nj/.local/lib/python3.12/site-packages (0.9.5)
# Requirement already satisfied: filelock in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (4.12.2)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torch) (3.3.1)
# Requirement already satisfied: numpy in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: bcrypt==4.1.2 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (4.1.2)
# Requirement already satisfied: boto3==1.34.56 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (1.34.56)
# Requirement already satisfied: forbiddenfruit==0.1.4 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (0.1.4)
# Requirement already satisfied: packaging>=23.0 in /usr/lib/python3/dist-packages (from syft) (24.0)
# Requirement already satisfied: pyarrow==17.0.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (17.0.0)
# Requirement already satisfied: pycapnp==2.0.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (2.0.0)
# Requirement already satisfied: pydantic[email]>=2.6.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (2.10.6)
# Requirement already satisfied: pydantic-settings>=2.2.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (2.7.1)
# Requirement already satisfied: pynacl==1.5.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (1.5.0)
# Requirement already satisfied: pyzmq<=25.1.1,>=23.2.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (25.1.1)
# Requirement already satisfied: requests==2.32.3 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (2.32.3)
# Requirement already satisfied: RestrictedPython==7.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (7.0)
# Requirement already satisfied: tqdm>=4.66.4 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (4.67.1)
# Requirement already satisfied: typeguard==4.1.5 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (4.1.5)
# Requirement already satisfied: sherlock[filelock]==0.4.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (0.4.1)
# Requirement already satisfied: uvicorn[standard]>=0.30.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (0.34.0)
# Requirement already satisfied: markdown==3.5.2 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (3.5.2)
# Requirement already satisfied: fastapi>=0.111.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (0.115.7)
# Requirement already satisfied: psutil>=6.0.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (6.1.1)
# Requirement already satisfied: itables==1.7.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (1.7.1)
# Requirement already satisfied: argon2-cffi==23.1.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (23.1.0)
# Requirement already satisfied: matplotlib<3.9.1,>=3.7.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (3.9.0)
# Requirement already satisfied: pandas==2.2.2 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (2.2.2)
# Requirement already satisfied: docker==7.1.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (7.1.0)
# Requirement already satisfied: kr8s==0.13.5 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (0.13.5)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (6.0.2)
# Requirement already satisfied: azure-storage-blob==12.19.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (12.19.1)
# Requirement already satisfied: ipywidgets==8.1.2 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (8.1.2)
# Requirement already satisfied: tomli==2.0.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (2.0.1)
# Requirement already satisfied: tomli_w==1.0.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (1.0.0)
# Requirement already satisfied: rich>=13.7.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (13.9.4)
# Requirement already satisfied: tenacity==8.3.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (8.3.0)
# Requirement already satisfied: nh3==0.2.17 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (0.2.17)
# Requirement already satisfied: psycopg[binary]==3.1.19 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (3.1.19)
# Requirement already satisfied: ipython<8.27.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (8.26.0)
# Requirement already satisfied: dynaconf==3.2.6 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (3.2.6)
# Requirement already satisfied: sqlalchemy==2.0.32 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (2.0.32)
# Requirement already satisfied: psycopg2-binary==2.9.9 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (2.9.9)
# Requirement already satisfied: syft-core==0.1.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (0.1.0)
# Requirement already satisfied: syft-event==0.1.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (0.1.0)
# Requirement already satisfied: syft-rpc==0.1.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (0.1.0)
# Requirement already satisfied: syftbox==0.3.5 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft) (0.3.5)
# Requirement already satisfied: argon2-cffi-bindings in /home/MacNight_nj/.local/lib/python3.12/site-packages (from argon2-cffi==23.1.0->syft) (21.2.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from azure-storage-blob==12.19.1->syft) (1.35.0)
# Requirement already satisfied: cryptography>=2.1.4 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from azure-storage-blob==12.19.1->syft) (44.0.3)
# Requirement already satisfied: isodate>=0.6.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from azure-storage-blob==12.19.1->syft) (0.7.2)
# Requirement already satisfied: botocore<1.35.0,>=1.34.56 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from boto3==1.34.56->syft) (1.34.162)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from boto3==1.34.56->syft) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from boto3==1.34.56->syft) (0.10.4)
# Requirement already satisfied: urllib3>=1.26.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from docker==7.1.0->syft) (2.5.0)
# Requirement already satisfied: comm>=0.1.3 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from ipywidgets==8.1.2->syft) (0.2.2)
# Requirement already satisfied: traitlets>=4.3.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from ipywidgets==8.1.2->syft) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from ipywidgets==8.1.2->syft) (4.0.14)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from ipywidgets==8.1.2->syft) (3.0.15)
# Requirement already satisfied: aiohttp>=3.8.4 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from kr8s==0.13.5->syft) (3.12.14)
# Requirement already satisfied: anyio>=3.7.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from kr8s==0.13.5->syft) (4.9.0)
# Requirement already satisfied: asyncache>=0.3.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from kr8s==0.13.5->syft) (0.3.1)
# Requirement already satisfied: httpx>=0.24.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from kr8s==0.13.5->syft) (0.28.1)
# Requirement already satisfied: python-box>=7.0.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from kr8s==0.13.5->syft) (7.3.2)
# Requirement already satisfied: python-jsonpath>=0.7.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from kr8s==0.13.5->syft) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from pandas==2.2.2->syft) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from pandas==2.2.2->syft) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from pandas==2.2.2->syft) (2025.2)
# Requirement already satisfied: psycopg-binary==3.1.19 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from psycopg[binary]==3.1.19->syft) (3.1.19)
# Requirement already satisfied: psycopg-pool in /home/MacNight_nj/.local/lib/python3.12/site-packages (from psycopg[binary]==3.1.19->syft) (3.2.6)
# Requirement already satisfied: cffi>=1.4.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from pynacl==1.5.0->syft) (1.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from requests==2.32.3->syft) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from requests==2.32.3->syft) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from requests==2.32.3->syft) (2025.7.14)
# Requirement already satisfied: greenlet!=0.4.17 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from sqlalchemy==2.0.32->syft) (3.2.3)
# Requirement already satisfied: loguru>=0.7.3 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft-event==0.1.0->syft) (0.7.3)
# Requirement already satisfied: pathspec>=0.12.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft-event==0.1.0->syft) (0.12.1)
# Requirement already satisfied: watchdog>=6.0.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syft-event==0.1.0->syft) (6.0.0)
# Requirement already satisfied: aiofiles>=24.1.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syftbox==0.3.5->syft) (24.1.0)
# Requirement already satisfied: croniter==6.0.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syftbox==0.3.5->syft) (6.0.0)
# Requirement already satisfied: curl-cffi>=0.7.4 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syftbox==0.3.5->syft) (0.12.0)
# Requirement already satisfied: distro==1.9.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syftbox==0.3.5->syft) (1.9.0)
# Requirement already satisfied: gunicorn==23.0.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syftbox==0.3.5->syft) (23.0.0)
# Requirement already satisfied: msgpack>=1.1.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syftbox==0.3.5->syft) (1.1.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.29.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syftbox==0.3.5->syft) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi==0.50b0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syftbox==0.3.5->syft) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation-sqlite3==0.50b0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syftbox==0.3.5->syft) (0.50b0)
# Requirement already satisfied: pid==3.0.4 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syftbox==0.3.5->syft) (3.0.4)
# Requirement already satisfied: py-fast-rsync==0.1.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syftbox==0.3.5->syft) (0.1.0)
# Requirement already satisfied: pyjwt==2.10.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syftbox==0.3.5->syft) (2.10.1)
# Requirement already satisfied: python-multipart==0.0.20 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syftbox==0.3.5->syft) (0.0.20)
# Requirement already satisfied: textual>=1.0.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syftbox==0.3.5->syft) (4.0.0)
# Requirement already satisfied: typer==0.15.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syftbox==0.3.5->syft) (0.15.1)
# Requirement already satisfied: wcmatch==10.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from syftbox==0.3.5->syft) (10.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from fastapi>=0.111.0->syft) (0.45.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from pydantic-settings>=2.2.1->syft) (1.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from pydantic[email]>=2.6.0->syft) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from pydantic[email]>=2.6.0->syft) (2.27.2)
# Requirement already satisfied: email-validator>=2.0.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from pydantic[email]>=2.6.0->syft) (2.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from rich>=13.7.1->syft) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/lib/python3/dist-packages (from rich>=13.7.1->syft) (2.17.2)
# Requirement already satisfied: httpcore==1.* in /home/MacNight_nj/.local/lib/python3.12/site-packages (from httpx>=0.24.1->kr8s==0.13.5->syft) (1.0.9)
# Requirement already satisfied: deprecated>=1.2.6 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->syftbox==0.3.5->syft) (1.2.18)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->syftbox==0.3.5->syft) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->syftbox==0.3.5->syft) (1.73.1)
# Requirement already satisfied: opentelemetry-api~=1.15 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->syftbox==0.3.5->syft) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->syftbox==0.3.5->syft) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->syftbox==0.3.5->syft) (1.29.0)
# Requirement already satisfied: opentelemetry-sdk~=1.29.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->syftbox==0.3.5->syft) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.50b0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi==0.50b0->syftbox==0.3.5->syft) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi==0.50b0->syftbox==0.3.5->syft) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi==0.50b0->syftbox==0.3.5->syft) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi==0.50b0->syftbox==0.3.5->syft) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation-dbapi==0.50b0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from opentelemetry-instrumentation-sqlite3==0.50b0->syftbox==0.3.5->syft) (0.50b0)
# Requirement already satisfied: click>=8.0.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from typer==0.15.1->syftbox==0.3.5->syft) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from typer==0.15.1->syftbox==0.3.5->syft) (1.5.4)
# Requirement already satisfied: h11>=0.8 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from uvicorn[standard]>=0.30.0->syft) (0.16.0)
# Requirement already satisfied: bracex>=2.1.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from wcmatch==10.0->syftbox==0.3.5->syft) (2.6)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi==0.50b0->syftbox==0.3.5->syft) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi==0.50b0->syftbox==0.3.5->syft) (3.9.1)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from opentelemetry-proto==1.29.0->opentelemetry-exporter-otlp-proto-grpc==1.29.0->syftbox==0.3.5->syft) (5.29.5)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc==1.29.0->syftbox==0.3.5->syft) (8.5.0)
# Requirement already satisfied: decorator in /home/MacNight_nj/.local/lib/python3.12/site-packages (from ipython<8.27.0->syft) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from ipython<8.27.0->syft) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/MacNight_nj/.local/lib/python3.12/site-packages (from ipython<8.27.0->syft) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from ipython<8.27.0->syft) (3.0.51)
# Requirement already satisfied: stack-data in /home/MacNight_nj/.local/lib/python3.12/site-packages (from ipython<8.27.0->syft) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from ipython<8.27.0->syft) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from matplotlib<3.9.1,>=3.7.1->syft) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from matplotlib<3.9.1,>=3.7.1->syft) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from matplotlib<3.9.1,>=3.7.1->syft) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from matplotlib<3.9.1,>=3.7.1->syft) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from matplotlib<3.9.1,>=3.7.1->syft) (3.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: httptools>=0.6.3 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from uvicorn[standard]>=0.30.0->syft) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from uvicorn[standard]>=0.30.0->syft) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from uvicorn[standard]>=0.30.0->syft) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from uvicorn[standard]>=0.30.0->syft) (15.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from aiohttp>=3.8.4->kr8s==0.13.5->syft) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from aiohttp>=3.8.4->kr8s==0.13.5->syft) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from aiohttp>=3.8.4->kr8s==0.13.5->syft) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from aiohttp>=3.8.4->kr8s==0.13.5->syft) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from aiohttp>=3.8.4->kr8s==0.13.5->syft) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from aiohttp>=3.8.4->kr8s==0.13.5->syft) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from aiohttp>=3.8.4->kr8s==0.13.5->syft) (1.20.1)
# Requirement already satisfied: sniffio>=1.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from anyio>=3.7.0->kr8s==0.13.5->syft) (1.3.1)
# Requirement already satisfied: cachetools<6.0.0,>=5.2.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from asyncache>=0.3.1->kr8s==0.13.5->syft) (5.5.2)
# Requirement already satisfied: six>=1.11.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob==12.19.1->syft) (1.17.0)
# Requirement already satisfied: pycparser in /home/MacNight_nj/.local/lib/python3.12/site-packages (from cffi>=1.4.1->pynacl==1.5.0->syft) (2.22)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/lib/python3/dist-packages (from email-validator>=2.0.0->pydantic[email]>=2.6.0->syft) (2.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from jedi>=0.16->ipython<8.27.0->syft) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->syft) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from pexpect>4.3->ipython<8.27.0->syft) (0.7.0)
# Requirement already satisfied: wcwidth in /home/MacNight_nj/.local/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<8.27.0->syft) (0.2.13)
# Requirement already satisfied: platformdirs<5,>=3.6.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from textual>=1.0.0->syftbox==0.3.5->syft) (4.3.8)
# Requirement already satisfied: executing>=1.2.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from stack-data->ipython<8.27.0->syft) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from stack-data->ipython<8.27.0->syft) (3.0.0)
# Requirement already satisfied: pure-eval in /home/MacNight_nj/.local/lib/python3.12/site-packages (from stack-data->ipython<8.27.0->syft) (0.2.3)
# Requirement already satisfied: linkify-it-py<3,>=1 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->syft) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in /home/MacNight_nj/.local/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->syft) (0.4.2)
# Requirement already satisfied: zipp>=3.20 in /home/MacNight_nj/.local/lib/python3.12/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc==1.29.0->syftbox==0.3.5->syft) (3.23.0)
# Requirement already satisfied: uc-micro-py in /home/MacNight_nj/.local/lib/python3.12/site-packages (from linkify-it-py<3,>=1->markdown-it-py>=2.2.0->rich>=13.7.1->syft) (1.0.3)
# WARNING: Skipping /usr/lib/python3.12/dist-packages/tqdm-4.66.5.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Skipping /usr/lib/python3.12/dist-packages/tqdm-4.66.5.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: pysyft in /home/MacNight_nj/.local/lib/python3.12/site-packages (0.0.1)
# WARNING: Skipping /usr/lib/python3.12/dist-packages/tqdm-4.66.5.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms
import syft as sy
import copy

# %%
class SimpleNet(nn.Module):
    def __init__(self):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
transform = transforms.Compose([transforms.ToTensor()])

# Load dataset once
full_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)

# Split for 2 clients (simulate decentralized data)
client1_data = Subset(full_dataset, range(0, 30000))
client2_data = Subset(full_dataset, range(30000, 60000))

client1_loader = DataLoader(client1_data, batch_size=64, shuffle=True)
client2_loader = DataLoader(client2_data, batch_size=64, shuffle=True)

# %%
def local_train(model, loader, epochs=1, lr=0.01):
    model.train()
    optimizer = torch.optim.SGD(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()

    for _ in range(epochs):
        for data, target in loader:
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
    return model.state_dict()

# %%
def average_weights(weights_list):
    avg_weights = copy.deepcopy(weights_list[0])
    for key in avg_weights:
        for i in range(1, len(weights_list)):
            avg_weights[key] += weights_list[i][key]
        avg_weights[key] = avg_weights[key] / len(weights_list)
    return avg_weights

# %%
global_model = SimpleNet()

rounds = 5
for r in range(rounds):
    print(f"\n📦 Round {r + 1}")

    # Copy global model for local training
    local_model1 = SimpleNet()
    local_model1.load_state_dict(global_model.state_dict())

    local_model2 = SimpleNet()
    local_model2.load_state_dict(global_model.state_dict())

    # Local training
    w1 = local_train(local_model1, client1_loader)
    w2 = local_train(local_model2, client2_loader)

    # Federated averaging
    new_weights = average_weights([w1, w2])
    global_model.load_state_dict(new_weights)
    print(f"✅ Round {r + 1} complete")
print("\n🎉 Federated Learning Training Complete!")
# Out:
# 📦 Round 1
# ✅ Round 1 complete
#
# 📦 Round 2
# ✅ Round 2 complete
#
# 📦 Round 3
# ✅ Round 3 complete
#
# 📦 Round 4
# ✅ Round 4 complete
#
# 📦 Round 5
# ✅ Round 5 complete
#
# 🎉 Federated Learning Training Complete!

# %%
test_loader = DataLoader(datasets.MNIST(root='./data', train=False, transform=transform), batch_size=64)

def evaluate(model, loader):
    model.eval()
    correct = 0
    with torch.no_grad():
        for data, target in loader:
            output = model(data)
            pred = output.argmax(dim=1)
            correct += (pred == target).sum().item()
    accuracy = correct / len(loader.dataset)
    print(f"✅ Global model accuracy: {accuracy:.4f}")

evaluate(global_model, test_loader)
# Out:
# ✅ Global model accuracy: 0.9002

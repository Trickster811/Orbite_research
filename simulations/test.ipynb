# %%
# Example usage and demonstration
def main():
    # Create simulation
    sim = NetworkSimulator()
    
    # Add IoT devices with different initial battery levels
    device_configs = [
        ("sensor_001", 95.0),
        ("sensor_002", 80.0),
        ("sensor_003", 60.0),
        ("actuator_001", 90.0),
        ("camera_001", 40.0)
    ]
    
    for device_id, battery in device_configs:
        sim.add_device(device_id, battery)
    
    print("IoT Network Simulation Started")
    print("=" * 50)
    
    # Run simulation
    final_report = sim.run_simulation(duration=80, step_delay=0.1)
    
    # Display final report
    print("\n" + "=" * 50)
    print("FINAL NETWORK REPORT")
    print("=" * 50)
    print(json.dumps(final_report, indent=2, default=str))
    
    # Create comprehensive dashboard with all visualizations
    print("\nGenerating comprehensive visual dashboard...")
    sim.create_comprehensive_dashboard()
    
    # Optional: Create real-time animated dashboard
    # Uncomment the line below to see real-time animation
    print("\nCreating real-time dashboard (close window to continue)...")
    sim.create_real_time_dashboard(duration=60)

def demo_quick_visualization():
    """Quick demo with immediate visualization"""
    print("Starting Quick IoT Monitoring Demo...")
    
    sim = NetworkSimulator()
    
    # Add devices
    devices = [("sensor_A", 85), ("sensor_B", 45), ("sensor_C", 70)]
    for device_id, battery in devices:
        sim.add_device(device_id, battery)
    
    # Run short simulation
    sim.run_simulation(duration=40, step_delay=0.05)
    
    # Show comprehensive dashboard
    sim.create_comprehensive_dashboard()

if __name__ == "__main__":
    # Choose which demo to run:
    # main()          # Full simulation with comprehensive dashboard
    demo_quick_visualization()  # Quick demo with immediate results
# Out:
# Starting Quick IoT Monitoring Demo...
# Device sensor_A registered with gateway
# Device sensor_B registered with gateway
# Device sensor_C registered with gateway
# Starting IoT network simulation for 40 steps...
#
# Step 0: Active devices: 3
# Total packets: 2
# ALERTS:
#   - LOW MEMORY: sensor_A - 12 KB free
#   - LOW MEMORY: sensor_B - 44 KB free
#   - LOW MEMORY: sensor_C - 22 KB free
#
# Step 20: Active devices: 3
# Total packets: 17
# ALERTS:
#   - LOW MEMORY: sensor_A - 16 KB free
#   - LOW MEMORY: sensor_B - 44 KB free
#   - HIGH PACKET LOSS: sensor_B - 13.7%
#
# Simulation completed!
# /tmp/ipykernel_120486/3952843229.py:499: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
